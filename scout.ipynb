# %%
import pandas as pd
import numpy as np
import sys
import time

pd.set_option("display.max_column",None)

# %% [markdown]
# # Using API Football
# https://www.api-football.com

# %% [markdown]
# ![PYTHON LOGO](https://www.api-football.com/public/img/news/archi-beta.jpg)

# %% [markdown]
# Image: https://www.api-football.com/public/img/news/archi-beta.jpg <br>
# Overview: https://rapidapi.com/api-sports/api/api-football/tutorials/how-to-use-the-api-football-api-with-python
#
#
# # Primary team in focus: Liverpool

# %% [markdown]
# # Data Pulls

# %%
# API Key and Configs
import requests
headers_rapid_api = {
	"X-RapidAPI-Key": "64f82034damsh6dd2baeda9216d1p173668jsnddc6687707f5",
	"X-RapidAPI-Host": "api-football-v1.p.rapidapi.com"
}
headers_api_sport = {
	"x-apisports-key": "0a078f979ea1996d42df390199afe0cf",
	"X-apisports-Host": "https://v3.football.api-sports.io/"
}

# %%
# Countries
country_url = "https://api-football-vi.p.rapidapi.com/v2/countries"
country_dat = requests.get(country_url,headers=headers)
country = pd.json_normalize(country_dat.json()['api']['countries'])
country

# %%
print(country[country.country == "England"])
# League
league_url = "https://api-football-v1.p.rapidapi.com/v3/leagues"
all_leagues = requests.get(league_url,headers=headers)
leagues_dat = pd.json_normalize(all_leagues.json()['response'])
# Out:
#     country code                                      flag
# 48  England   GB  https://media.api-sports.io/flags/gb.svg

# %% [markdown]
# country code                                      flag
# 48  England   GB  https://media.api-sports.io/flags/gb.svg

# %%
# EPl
leagues_dat[(leagues_dat['league.name'] == "Premier League") & (leagues_dat['country.name'] == "England")]
epl_id = leagues_dat[(leagues_dat['league.name'] == "Premier League") & (leagues_dat['country.name'] == "England")]['league.id']
epl_id
# Out:
# 5    39
# Name: league.id, dtype: int64

# %% [markdown]
# EPL ID: 39

# %%
# Premier League Players
# read 50 * 20 players from Premier League 
players_dat = dict()
for i in range(10):
    page = i+1
    player_url = "https://api-football-v1.p.rapidapi.com/v3/players?season=2018&league=39&page={}".format(page)
    #querystring = {"league":"39","season":"2023"}
    players_dat[page] = pd.json_normalize(requests.get(player_url, headers=headers).json()['response'])

players_dat_final = pd.concat(list(players_dat.values()),ignore_index=True)
players_dat_final.shape
# Out:
# (200, 14)

# %%
players_dat_final
#players_dat = pd.concat(players_dat,ignore_index=True)
# Out:
#                                             statistics  player.id  \
# 0    [{'team': {'id': 39, 'name': 'Wolves', 'logo':...         54
# 1    [{'team': {'id': 47, 'name': 'Tottenham', 'log...        178
# 2    [{'team': {'id': 40, 'name': 'Liverpool', 'log...        297
# 3    [{'team': {'id': 33, 'name': 'Manchester Unite...        888
# 4    [{'team': {'id': 65, 'name': 'Nottingham Fores...        900
# ..                                                 ...        ...
# 195  [{'team': {'id': 44, 'name': 'Burnley', 'logo'...     284212
# 196  [{'team': {'id': 40, 'name': 'Liverpool', 'log...     284366
# 197  [{'team': {'id': 55, 'name': 'Brentford', 'log...     284474
# 198  [{'team': {'id': 52, 'name': 'Crystal Palace',...     308867
# 199  [{'team': {'id': 35, 'name': 'Bournemouth', 'l...     382160
#
#                player.name        player.firstname           player.lastname  \
# 0              Diego Costa                   Diego            da Silva Costa
# 1              Lucas Moura                   Lucas  Rodrigues Moura da Silva
# 2    A. Oxlade-Chamberlain    Alexander Mark David        Oxlade-Chamberlain
# 3                 P. Jones            Phil Anthony                     Jones
# 4               J. Lingard             Jesse Ellis                   Lingard
# ..                     ...                     ...                       ...
# 195               D. Sassi                  Daniel                     Sassi
# 196            L. Chambers                    Luke                  Chambers
# 197            M. Olakigbe     Michael Oluwakorede                  Olakigbe
# 198              S. Grehan                    Seán                    Grehan
# 199           D. Adu-Adjei  Daniel William Kwabena                 Adu-Adjei
#
#      player.age player.birth.date player.birth.place player.birth.country  \
# 0            35        1988-10-07            Lagarto               Brazil
# 1            31        1992-08-13          São Paulo               Brazil
# 2            30        1993-08-15         Portsmouth              England
# 3            31        1992-02-21            Preston              England
# 4            31        1992-12-15         Warrington              England
# ..          ...               ...                ...                  ...
# 195          21        2003-12-08               None              England
# 196          20        2004-06-24               None              England
# 197          20        2004-04-25               None              Nigeria
# 198          20        2004-01-08               None  Republic of Ireland
# 199          19        2005-06-21               None              England
#
#       player.nationality player.height player.weight  player.injured  \
# 0                  Spain        188 cm         83 kg           False
# 1                 Brazil        172 cm         72 kg           False
# 2                England        180 cm         70 kg           False
# 3                England        180 cm         71 kg           False
# 4                England        175 cm         62 kg           False
# ..                   ...           ...           ...             ...
# 195              England          None          None           False
# 196              England          None          None           False
# 197              England          None          None           False
# 198  Republic of Ireland          None          None           False
# 199              England        177 cm          None           False
#
#                                           player.photo
# 0    https://media.api-sports.io/football/players/5...
# 1    https://media.api-sports.io/football/players/1...
# 2    https://media.api-sports.io/football/players/2...
# 3    https://media.api-sports.io/football/players/8...
# 4    https://media.api-sports.io/football/players/9...
# ..                                                 ...
# 195  https://media.api-sports.io/football/players/2...
# 196  https://media.api-sports.io/football/players/2...
# 197  https://media.api-sports.io/football/players/2...
# 198  https://media.api-sports.io/football/players/3...
# 199  https://media.api-sports.io/football/players/3...
#
# [200 rows x 14 columns]

# %%
if players_dat:  # Check if the list is not empty
    players_dat_final = pd.concat(players_dat, ignore_index=True)
    print(result)
else:
    print("No DataFrames found to concatenate.")
# Out:
# No DataFrames found to concatenate.

# %%
players_dat = pd.json_normalize(epl_players.json()['response'])
players_dat
# Out:
#                                            statistics  player.id  \
# 0   [{'team': {'id': 39, 'name': 'Wolves', 'logo':...         54
# 1   [{'team': {'id': 47, 'name': 'Tottenham', 'log...        178
# 2   [{'team': {'id': 40, 'name': 'Liverpool', 'log...        297
# 3   [{'team': {'id': 33, 'name': 'Manchester Unite...        888
# 4   [{'team': {'id': 65, 'name': 'Nottingham Fores...        900
# 5   [{'team': {'id': 48, 'name': 'West Ham', 'logo...       2473
# 6   [{'team': {'id': 39, 'name': 'Wolves', 'logo':...       2677
# 7   [{'team': {'id': 39, 'name': 'Wolves', 'logo':...      18753
# 8   [{'team': {'id': 45, 'name': 'Everton', 'logo'...      18762
# 9   [{'team': {'id': 52, 'name': 'Crystal Palace',...      18849
# 10  [{'team': {'id': 52, 'name': 'Crystal Palace',...      18852
# 11  [{'team': {'id': 45, 'name': 'Everton', 'logo'...      18854
# 12  [{'team': {'id': 45, 'name': 'Everton', 'logo'...      18858
# 13  [{'team': {'id': 35, 'name': 'Bournemouth', 'l...      18878
# 14  [{'team': {'id': 62, 'name': 'Sheffield Utd', ...      18891
# 15  [{'team': {'id': 66, 'name': 'Aston Villa', 'l...      19174
# 16  [{'team': {'id': 65, 'name': 'Nottingham Fores...      19299
# 17  [{'team': {'id': 65, 'name': 'Nottingham Fores...      19842
# 18  [{'team': {'id': 34, 'name': 'Newcastle', 'log...     130419
# 19  [{'team': {'id': 49, 'name': 'Chelsea', 'logo'...     181822
#
#               player.name      player.firstname           player.lastname  \
# 0             Diego Costa                 Diego            da Silva Costa
# 1             Lucas Moura                 Lucas  Rodrigues Moura da Silva
# 2   A. Oxlade-Chamberlain  Alexander Mark David        Oxlade-Chamberlain
# 3                P. Jones          Phil Anthony                     Jones
# 4              J. Lingard           Jesse Ellis                   Lingard
# 5              M. Lanzini                Manuel                   Lanzini
# 6           João Moutinho           João Filipe      Iria Santos Moutinho
# 7            Adama Traoré                 Adama             Traoré Diarra
# 8               T. Davies                Thomas                    Davies
# 9             J. McArthur                 James        McFarlane McArthur
# 10         L. Milivojević                  Luka               Milivojević
# 11            A. Townsend         Andros Darryl                  Townsend
# 12             A. Begović                 Asmir                   Begović
# 13           J. Stanislas          Felix Junior                 Stanislas
# 14               C. Clark                Ciaran                     Clark
# 15               J. Steer              Jed John                     Steer
# 16             J. Colback          Jack Raymond                   Colback
# 17              L. Taylor     Lyle James Alfred                    Taylor
# 18           M. Longstaff           Matthew Ben                 Longstaff
# 19                E. Wady           Ethan James                      Wady
#
#     player.age player.birth.date         player.birth.place  \
# 0           35        1988-10-07                    Lagarto
# 1           31        1992-08-13                  São Paulo
# 2           30        1993-08-15                 Portsmouth
# 3           31        1992-02-21                    Preston
# 4           31        1992-12-15                 Warrington
# 5           30        1993-02-15                  Ituzaingó
# 6           37        1986-09-08                   Portimão
# 7           28        1996-01-25  L'Hospitalet de Llobregat
# 8           26        1998-06-30                  Liverpool
# 9           36        1987-10-07                    Glasgow
# 10          32        1991-04-07                 Kragujevac
# 11          33        1991-07-16                     London
# 12          36        1987-06-20                   Trebinje
# 13          34        1989-11-26                  Kidbrooke
# 14          34        1989-09-26                     London
# 15          31        1992-09-23                    Norwich
# 16          34        1989-10-24               Killingworth
# 17          33        1990-03-29                  Greenwich
# 18          23        2000-03-21                       None
# 19          21        2002-01-23                   San Jose
#
#       player.birth.country      player.nationality player.height  \
# 0                   Brazil                   Spain        188 cm
# 1                   Brazil                  Brazil        172 cm
# 2                  England                 England        180 cm
# 3                  England                 England        180 cm
# 4                  England                 England        175 cm
# 5                Argentina               Argentina        167 cm
# 6                 Portugal                Portugal        170 cm
# 7                    Spain                   Spain        178 cm
# 8                  England                 England        180 cm
# 9                 Scotland                Scotland        178 cm
# 10              Yugoslavia                  Serbia        186 cm
# 11                 England                 England        181 cm
# 12  Bosnia and Herzegovina  Bosnia and Herzegovina        199 cm
# 13                 England                 England        183 cm
# 14                 England     Republic of Ireland        185 cm
# 15                 England                 England        183 cm
# 16                 England                 England        177 cm
# 17                 England              Montserrat        188 cm
# 18                 England                 England          None
# 19                     USA                     USA          None
#
#    player.weight  player.injured  \
# 0          83 kg           False
# 1          72 kg           False
# 2          70 kg           False
# 3          71 kg           False
# 4          62 kg           False
# 5          59 kg           False
# 6          61 kg           False
# 7          86 kg           False
# 8          70 kg           False
# 9          75 kg           False
# 10         80 kg           False
# 11         77 kg           False
# 12        101 kg           False
# 13         76 kg           False
# 14         88 kg           False
# 15         80 kg           False
# 16         77 kg           False
# 17         75 kg           False
# 18          None           False
# 19          None           False
#
#                                          player.photo
# 0   https://media.api-sports.io/football/players/5...
# 1   https://media.api-sports.io/football/players/1...
# 2   https://media.api-sports.io/football/players/2...
# 3   https://media.api-sports.io/football/players/8...
# 4   https://media.api-sports.io/football/players/9...
# 5   https://media.api-sports.io/football/players/2...
# 6   https://media.api-sports.io/football/players/2...
# 7   https://media.api-sports.io/football/players/1...
# 8   https://media.api-sports.io/football/players/1...
# 9   https://media.api-sports.io/football/players/1...
# 10  https://media.api-sports.io/football/players/1...
# 11  https://media.api-sports.io/football/players/1...
# 12  https://media.api-sports.io/football/players/1...
# 13  https://media.api-sports.io/football/players/1...
# 14  https://media.api-sports.io/football/players/1...
# 15  https://media.api-sports.io/football/players/1...
# 16  https://media.api-sports.io/football/players/1...
# 17  https://media.api-sports.io/football/players/1...
# 18  https://media.api-sports.io/football/players/1...
# 19  https://media.api-sports.io/football/players/1...

# %%
players_dat_stats = pd.json_normalize(players_dat['statistics'])
players_dat_stats_first_team = pd.json_normalize(players_dat_stats[0])
players_dat_stats_transfer_team = pd.json_normalize(players_dat_stats[1])

# %%
players_dat_stats.head()
# Out:
#                                                    0     1
# 0  {'team.id': 39, 'team.name': 'Wolves', 'team.l...  None
# 1  {'team.id': 47, 'team.name': 'Tottenham', 'tea...  None
# 2  {'team.id': 40, 'team.name': 'Liverpool', 'tea...  None
# 3  {'team.id': 33, 'team.name': 'Manchester Unite...  None
# 4  {'team.id': 65, 'team.name': 'Nottingham Fores...  None

# %% [markdown]
# # ***Main Players and Fixtures Data Read*** ---->

# %%
# Configs
team = "Liverpool" # team to pull players data of
season = 2022 # season to pull players and teams stats of
league = 39 # league ID to pull from, current values: {39:premier league}

# %%
# Fixtures for Events Data
## Main Entry point to get match summary and drill down with fixture ids
url = "https://v3.football.api-sports.io/fixtures?league={}&season={}".format(league,season)
fixtures_response = requests.get(url,headers=headers_api_sport)
fixtures_dat = pd.json_normalize(fixtures_response.json()['response'])
fixtures_dat.head()

# %%
# Liverpools Fixtures for the 2022 season
liverpool_fixtures = fixtures_dat[(fixtures_dat['teams.home.name'] == team) | (fixtures_dat['teams.away.name'] == team)]
liverpool_fixtures_id = liverpool_fixtures[['fixture.id','teams.home.name','teams.away.name']]
liverpool_fixtures_id.head()
# Out:
#     fixture.id    teams.home.name teams.away.name
# 1       867947             Fulham       Liverpool
# 15      867961          Liverpool  Crystal Palace
# 26      867972  Manchester United       Liverpool
# 35      867981          Liverpool     Bournemouth
# 48      867994          Liverpool       Newcastle

# %%
print("Number of Liverpool fixtures to read: ",len(liverpool_fixtures_id))
# Out:
# Number of Liverpool fixtures to read:  38

# %%
# Read player statistics for Liverpool
## There is a API call rate limit of 10 requests per minute
## Add sleep for a minute

player_stat_home = dict()
player_stat_away = dict()
#home Games
for fixture in liverpool_fixtures_id[liverpool_fixtures_id['teams.home.name'] == "Liverpool"]['fixture.id']:
    player_stat_url = "https://v3.football.api-sports.io/fixtures/players?fixture={}".format(fixture)
    player_stat_home[fixture] = requests.get(player_stat_url,headers=headers_api_sport)
    
    time.sleep(15)
    
#Away Games
for fixture in liverpool_fixtures_id[liverpool_fixtures_id['teams.home.name'] != "Liverpool"]['fixture.id']:
    player_stat_url = "https://v3.football.api-sports.io/fixtures/players?fixture={}".format(fixture)
    player_stat_away[fixture] = requests.get(player_stat_url,headers=headers_api_sport)
    time.sleep(15)

# %%
print(player_stat_home.keys())
print(player_stat_away.keys())
# Out:
# dict_keys([867961, 867981, 867994, 868012, 868032, 868051, 868064, 868083, 868099, 868119, 868152, 868172, 868201, 868221, 868241, 868263, 868283, 868289, 868309])
# dict_keys([867947, 867972, 868000, 868019, 868037, 868071, 868093, 868107, 868128, 868138, 868165, 868182, 868187, 868206, 868232, 868249, 868270, 868303, 868325])

# %%
player_stat_away[867947].json()
# Out:
# {'get': 'fixtures/players',
#  'parameters': {'fixture': '867947'},
#  'errors': [],
#  'results': 2,
#  'paging': {'current': 1, 'total': 1},
#  'response': [{'team': {'id': 36,
#     'name': 'Fulham',
#     'logo': 'https://media.api-sports.io/football/teams/36.png',
#     'update': '2023-05-30T04:11:35+00:00'},
#    'players': [{'player': {'id': 19657,
#       'name': 'Marek Rodák',
#       'photo': 'https://media.api-sports.io/football/players/19657.png'},
#      'statistics': [{'games': {'minutes': 90,
#         'number': 1,
#         'position': 'G',
#         'rating': '6.3',
#         'captain': False,
#         'substitute': False},
#        'offsides': None,
#        'shots': {'total': None, 'on': None},
#        'goals': {'total': None, 'conceded': 2, 'assists': None, 'saves': 1},
#        'passes': {'total': 31, 'key': None, 'accuracy': '12'},
#        'tackles': {'total': None, 'blocks': None, 'interceptions': None},
#        'duels': {'total': 1, 'won': 1},
#        'dribbles': {'attempts': None, 'success': None, 'past': None},
#        'fouls': {'drawn': None, 'committed': None},
#        'cards': {'yellow': 0, 'red': 0},
#        'penalty': {'won': None,
#         'commited': None,
#         'scored': 0,
#         'missed': 0,
#         'saved': 0}}]},
#     {'player': {'id': 657,
#       'name': 'Kenny Tete',
#       'photo': 'https://media.api-sports.io/football/players/657.png'},
#      'statistics': [{'games': {'minutes': 90,
#         'number': 2,
#         'position': 'D',
#         'rating': '7.2',
#         'captain': False,
#         'substitute': False},
#        'offsides': None,
#        'shots': {'total': None, 'on': None},
#        'goals': {'total': None, 'conceded': 0, 'assists': 1, 'saves': None},
#        'passes': {'total': 30, 'key': 1, 'accuracy': '17'},
#        'tackles': {'total': 5, 'blocks': None, 'interceptions': 2},
#        'duels': {'total': 11, 'won': 7},
#        'dribbles': {'attempts': None, 'success': None, 'past': None},
#        'fouls': {'drawn': 1, 'committed': 1},
#        'cards': {'yellow': 1, 'red': 0},
#        'penalty': {'won': None,
#         'commited': None,
#         'scored': 0,
#         'missed': 0,
#         'saved': None}}]},
#     {'player': {'id': 19145,
#       'name': 'Tosin Adarabioyo',
#       'photo': 'https://media.api-sports.io/football/players/19145.png'},
#      'statistics': [{'games': {'minutes': 90,
#         'number': 4,
#         'position': 'D',
#         'rating': '6.9',
#         'captain': False,
#         'substitute': False},
#        'offsides': None,
#        'shots': {'total': None, 'on': None},
#        'goals': {'total': None, 'conceded': 0, 'assists': None, 'saves': None},
#        'passes': {'total': 26, 'key': None, 'accuracy': '17'},
#        'tackles': {'total': 2, 'blocks': None, 'interceptions': 1},
#        'duels': {'total': 4, 'won': 4},
#        'dribbles': {'attempts': None, 'success': None, 'past': None},
#        'fouls': {'drawn': None, 'committed': None},
#        'cards': {'yellow': 0, 'red': 0},
#        'penalty': {'won': None,
#         'commited': None,
#         'scored': 0,
#         'missed': 0,
#         'saved': None}}]},
#     {'player': {'id': 19023,
#       'name': 'Tim Ream',
#       'photo': 'https://media.api-sports.io/football/players/19023.png'},
#      'statistics': [{'games': {'minutes': 90,
#         'number': 13,
#         'position': 'M',
#         'rating': '7.2',
#         'captain': True,
#         'substitute': False},
#        'offsides': None,
#        'shots': {'total': None, 'on': None},
#        'goals': {'total': None, 'conceded': 0, 'assists': None, 'saves': None},
#        'passes': {'total': 27, 'key': None, 'accuracy': '19'},
#        'tackles': {'total': 1, 'blocks': 1, 'interceptions': 1},
#        'duels': {'total': 4, 'won': 3},
#        'dribbles': {'attempts': 1, 'success': 1, 'past': 1},
#        'fouls': {'drawn': None, 'committed': None},
#        'cards': {'yellow': 0, 'red': 0},
#        'penalty': {'won': None,
#         'commited': None,
#         'scored': 0,
#         'missed': 0,
#         'saved': None}}]},
#     {'player': {'id': 19549,
#       'name': 'Antonee Robinson',
#       'photo': 'https://media.api-sports.io/football/players/19549.png'},
#      'statistics': [{'games': {'minutes': 90,
#         'number': 33,
#         'position': 'D',
#         'rating': '6.5',
#         'captain': False,
#         'substitute': False},
#        'offsides': None,
#        'shots': {'total': None, 'on': None},
#        'goals': {'total': None, 'conceded': 0, 'assists': None, 'saves': None},
#        'passes': {'total': 34, 'key': None, 'accuracy': '22'},
#        'tackles': {'total': 1, 'blocks': None, 'interceptions': 2},
#        'duels': {'total': 3, 'won': 1},
#        'dribbles': {'attempts': None, 'success': None, 'past': 1},
#        'fouls': {'drawn': None, 'committed': 1},
#        'cards': {'yellow': 0, 'red': 0},
#        'penalty': {'won': None,
#         'commited': None,
#         'scored': 0,
#         'missed': 0,
#         'saved': None}}]},
#     {'player': {'id': 19480,
#       'name': 'Harrison Reed',
#       'photo': 'https://media.api-sports.io/football/players/19480.png'},
#      'statistics': [{'games': {'minutes': 90,
#         'number': 6,
#         'position': 'M',
#         'rating': '6.9',
#         'captain': False,
#         'substitute': False},
#        'offsides': None,
#        'shots': {'total': None, 'on': None},
#        'goals': {'total': None, 'conceded': 0, 'assists': None, 'saves': None},
#        'passes': {'total': 31, 'key': 1, 'accuracy': '19'},
#        'tackles': {'total': 3, 'blocks': 1, 'interceptions': 2},
#        'duels': {'total': 9, 'won': 6},
#        'dribbles': {'attempts': 1, 'success': None, 'past': 1},
#        'fouls': {'drawn': None, 'committed': None},
#        'cards': {'yellow': 0, 'red': 0},
#        'penalty': {'won': None,
#         'commited': None,
#         'scored': 0,
#         'missed': 0,
#         'saved': None}}]},
#     {'player': {'id': 41104,
#       'name': 'João Palhinha',
#       'photo': 'https://media.api-sports.io/football/players/41104.png'},
#      'statistics': [{'games': {'minutes': 90,
#         'number': 26,
#         'position': 'D',
#         'rating': '7.2',
#         'captain': False,
#         'substitute': False},
#        'offsides': None,
#        'shots': {'total': None, 'on': None},
#        'goals': {'total': None, 'conceded': 0, 'assists': None, 'saves': None},
#        'passes': {'total': 26, 'key': None, 'accuracy': '20'},
#        'tackles': {'total': 6, 'blocks': None, 'interceptions': 1},
#        'duels': {'total': 14, 'won': 9},
#        'dribbles': {'attempts': None, 'success': None, 'past': None},
#        'fouls': {'drawn': 1, 'committed': 1},
#        'cards': {'yellow': 0, 'red': 0},
#        'penalty': {'won': None,
#         'commited': None,
#         'scored': 0,
#         'missed': 0,
#         'saved': None}}]},
#     {'player': {'id': 19027,
#       'name': 'Neeskens Kebano',
#       'photo': 'https://media.api-sports.io/football/players/19027.png'},
#      'statistics': [{'games': {'minutes': 66,
#         'number': 7,
#         'position': 'M',
#         'rating': '6.3',
#         'captain': False,
#         'substitute': False},
#        'offsides': 2,
#        'shots': {'total': 1, 'on': None},
#        'goals': {'total': None, 'conceded': 0, 'assists': None, 'saves': None},
#        'passes': {'total': 14, 'key': 1, 'accuracy': '11'},
#        'tackles': {'total': 1, 'blocks': None, 'interceptions': None},
#        'duels': {'total': 9, 'won': 3},
#        'dribbles': {'attempts': 2, 'success': 1, 'past': 1},
#        'fouls': {'drawn': 1, 'committed': 1},
#        'cards': {'yellow': 0, 'red': 0},
#        'penalty': {'won': None,
#         'commited': None,
#         'scored': 0,
#         'missed': 0,
#         'saved': None}}]},
#     {'player': {'id': 899,
#       'name': 'Andreas Pereira',
#       'photo': 'https://media.api-sports.io/football/players/899.png'},
#      'statistics': [{'games': {'minutes': 89,
#         'number': 18,
#         'position': 'M',
#         'rating': '6.5',
#         'captain': False,
#         'substitute': False},
#        'offsides': 1,
#        'shots': {'total': None, 'on': None},
#        'goals': {'total': None, 'conceded': 0, 'assists': None, 'saves': None},
#        'passes': {'total': 23, 'key': 1, 'accuracy': '14'},
#        'tackles': {'total': None, 'blocks': None, 'interceptions': None},
#        'duels': {'total': 4, 'won': 1},
#        'dribbles': {'attempts': 1, 'success': None, 'past': None},
#        'fouls': {'drawn': None, 'committed': 2},
#        'cards': {'yellow': 0, 'red': 0},
#        'penalty': {'won': None,
#         'commited': None,
#         'scored': 0,
#         'missed': 0,
#         'saved': None}}]},
#     {'player': {'id': 19004,
#       'name': 'Bobby Reid',
#       'photo': 'https://media.api-sports.io/football/players/19004.png'},
#      'statistics': [{'games': {'minutes': 89,
#         'number': 14,
#         'position': 'M',
#         'rating': '6.9',
#         'captain': False,
#         'substitute': False},
#        'offsides': None,
#        'shots': {'total': 1, 'on': 1},
#        'goals': {'total': None, 'conceded': 0, 'assists': None, 'saves': None},
#        'passes': {'total': 21, 'key': 1, 'accuracy': '18'},
#        'tackles': {'total': 2, 'blocks': None, 'interceptions': None},
#        'duels': {'total': 8, 'won': 5},
#        'dribbles': {'attempts': 1, 'success': 1, 'past': None},
#        'fouls': {'drawn': 1, 'committed': None},
#        'cards': {'yellow': 1, 'red': 0},
#        'penalty': {'won': None,
#         'commited': None,
#         'scored': 0,
#         'missed': 0,
#         'saved': None}}]},
#     {'player': {'id': 2825,
#       'name': 'Aleksandar Mitrović',
#       'photo': 'https://media.api-sports.io/football/players/2825.png'},
#      'statistics': [{'games': {'minutes': 90,
#         'number': 9,
#         'position': 'F',
#         'rating': '9.5',
#         'captain': False,
#         'substitute': False},
#        'offsides': 1,
#        'shots': {'total': 3, 'on': 2},
#        'goals': {'total': 2, 'conceded': 0, 'assists': None, 'saves': None},
#        'passes': {'total': 28, 'key': 1, 'accuracy': '10'},
#        'tackles': {'total': 1, 'blocks': 1, 'interceptions': 1},
#        'duels': {'total': 23, 'won': 18},
#        'dribbles': {'attempts': 2, 'success': 2, 'past': None},
#        'fouls': {'drawn': 4, 'committed': 1},
#        'cards': {'yellow': 0, 'red': 0},
#        'penalty': {'won': 1,
#         'commited': None,
#         'scored': 1,
#         'missed': 0,
#         'saved': None}}]},
#     {'player': {'id': 1438,
#       'name': 'Bernd Leno',
#       'photo': 'https://media.api-sports.io/football/players/1438.png'},
#      'statistics': [{'games': {'minutes': None,
#         'number': 17,
#         'position': 'G',
#         'rating': None,
#         'captain': False,
#         'substitute': True},
#        'offsides': None,
#        'shots': {'total': None, 'on': None},
#        'goals': {'total': None, 'conceded': 0, 'assists': None, 'saves': None},
#        'passes': {'total': None, 'key': None, 'accuracy': None},
#        'tackles': {'total': None, 'blocks': None, 'interceptions': None},
#        'duels': {'total': None, 'won': None},
#        'dribbles': {'attempts': None, 'success': None, 'past': None},
#        'fouls': {'drawn': None, 'committed': None},
#        'cards': {'yellow': 0, 'red': 0},
#        'penalty': {'won': None,
#         'commited': None,
#         'scored': 0,
#         'missed': 0,
#         'saved': None}}]},
#     {'player': {'id': 18962,
#       'name': 'Shane Duffy',
#       'photo': 'https://media.api-sports.io/football/players/18962.png'},
#      'statistics': [{'games': {'minutes': 1,
#         'number': 5,
#         'position': 'D',
#         'rating': None,
#         'captain': False,
#         'substitute': True},
#        'offsides': None,
#        'shots': {'total': None, 'on': None},
#        'goals': {'total': None, 'conceded': 0, 'assists': None, 'saves': None},
#        'passes': {'total': None, 'key': None, 'accuracy': None},
#        'tackles': {'total': None, 'blocks': None, 'interceptions': None},
#        'duels': {'total': None, 'won': None},
#        'dribbles': {'attempts': None, 'success': None, 'past': None},
#        'fouls': {'drawn': None, 'committed': None},
#        'cards': {'yellow': 0, 'red': 0},
#        'penalty': {'won': None,
#         'commited': None,
#         'scored': 0,
#         'missed': 0,
#         'saved': None}}]},
#     {'player': {'id': 946,
#       'name': 'Kevin Mbabu',
#       'photo': 'https://media.api-sports.io/football/players/946.png'},
#      'statistics': [{'games': {'minutes': None,
#         'number': 27,
#         'position': 'D',
#         'rating': None,
#         'captain': False,
#         'substitute': True},
#        'offsides': None,
#        'shots': {'total': None, 'on': None},
#        'goals': {'total': None, 'conceded': 0, 'assists': None, 'saves': None},
#        'passes': {'total': None, 'key': None, 'accuracy': None},
#        'tackles': {'total': None, 'blocks': None, 'interceptions': None},
#        'duels': {'total': None, 'won': None},
#        'dribbles': {'attempts': None, 'success': None, 'past': None},
#        'fouls': {'drawn': None, 'committed': None},
#        'cards': {'yellow': 0, 'red': 0},
#        'penalty': {'won': None,
#         'commited': None,
#         'scored': 0,
#         'missed': 0,
#         'saved': None}}]},
#     {'player': {'id': 129707,
#       'name': 'Tyrese Francois',
#       'photo': 'https://media.api-sports.io/football/players/129707.png'},
#      'statistics': [{'games': {'minutes': None,
#         'number': 35,
#         'position': 'M',
#         'rating': None,
#         'captain': False,
#         'substitute': True},
#        'offsides': None,
#        'shots': {'total': None, 'on': None},
#        'goals': {'total': None, 'conceded': 0, 'assists': None, 'saves': None},
#        'passes': {'total': None, 'key': None, 'accuracy': None},
#        'tackles': {'total': None, 'blocks': None, 'interceptions': None},
#        'duels': {'total': None, 'won': None},
#        'dribbles': {'attempts': None, 'success': None, 'past': None},
#        'fouls': {'drawn': None, 'committed': None},
#        'cards': {'yellow': 0, 'red': 0},
#        'penalty': {'won': None,
#         'commited': None,
#         'scored': 0,
#         'missed': 0,
#         'saved': None}}]},
#     {'player': {'id': 19025,
#       'name': 'Tom Cairney',
#       'photo': 'https://media.api-sports.io/football/players/19025.png'},
#      'statistics': [{'games': {'minutes': 1,
#         'number': 10,
#         'position': 'M',
#         'rating': None,
#         'captain': False,
#         'substitute': True},
#        'offsides': None,
#        'shots': {'total': None, 'on': None},
#        'goals': {'total': None, 'conceded': 0, 'assists': None, 'saves': None},
#        'passes': {'total': None, 'key': None, 'accuracy': None},
#        'tackles': {'total': 1, 'blocks': None, 'interceptions': None},
#        'duels': {'total': 1, 'won': 1},
#        'dribbles': {'attempts': None, 'success': None, 'past': None},
#        'fouls': {'drawn': None, 'committed': None},
#        'cards': {'yellow': 0, 'red': 0},
#        'penalty': {'won': None,
#         'commited': None,
#         'scored': 0,
#         'missed': 0,
#         'saved': None}}]},
#     {'player': {'id': 153077,
#       'name': 'Luke Harris',
#       'photo': 'https://media.api-sports.io/football/players/153077.png'},
#      'statistics': [{'games': {'minutes': None,
#         'number': 38,
#         'position': 'M',
#         'rating': None,
#         'captain': False,
#         'substitute': True},
#        'offsides': None,
#        'shots': {'total': None, 'on': None},
#        'goals': {'total': None, 'conceded': 0, 'assists': None, 'saves': None},
#        'passes': {'total': None, 'key': None, 'accuracy': None},
#        'tackles': {'total': None, 'blocks': None, 'interceptions': None},
#        'duels': {'total': None, 'won': None},
#        'dribbles': {'attempts': None, 'success': None, 'past': None},
#        'fouls': {'drawn': None, 'committed': None},
#        'cards': {'yellow': 0, 'red': 0},
#        'penalty': {'won': None,
#         'commited': None,
#         'scored': 0,
#         'missed': 0,
#         'saved': None}}]},
#     {'player': {'id': 697,
#       'name': 'Manor Solomon',
#       'photo': 'https://media.api-sports.io/football/players/697.png'},
#      'statistics': [{'games': {'minutes': 24,
#         'number': 11,
#         'position': 'F',
#         'rating': '6.3',
#         'captain': False,
#         'substitute': True},
#        'offsides': None,
#        'shots': {'total': None, 'on': None},
#        'goals': {'total': None, 'conceded': 0, 'assists': None, 'saves': None},
#        'passes': {'total': 3, 'key': None, 'accuracy': '2'},
#        'tackles': {'total': 2, 'blocks': None, 'interceptions': None},
#        'duels': {'total': 5, 'won': 2},
#        'dribbles': {'attempts': 2, 'success': None, 'past': None},
#        'fouls': {'drawn': None, 'committed': None},
#        'cards': {'yellow': 0, 'red': 0},
#        'penalty': {'won': None,
#         'commited': None,
#         'scored': 0,
#         'missed': 0,
#         'saved': None}}]},
#     {'player': {'id': 195106,
#       'name': 'Rodrigo Muniz',
#       'photo': 'https://media.api-sports.io/football/players/195106.png'},
#      'statistics': [{'games': {'minutes': None,
#         'number': 19,
#         'position': 'F',
#         'rating': None,
#         'captain': False,
#         'substitute': True},
#        'offsides': None,
#        'shots': {'total': None, 'on': None},
#        'goals': {'total': None, 'conceded': 0, 'assists': None, 'saves': None},
#        'passes': {'total': None, 'key': None, 'accuracy': None},
#        'tackles': {'total': None, 'blocks': None, 'interceptions': None},
#        'duels': {'total': None, 'won': None},
#        'dribbles': {'attempts': None, 'success': None, 'past': None},
#        'fouls': {'drawn': None, 'committed': None},
#        'cards': {'yellow': 0, 'red': 0},
#        'penalty': {'won': None,
#         'commited': None,
#         'scored': 0,
#         'missed': 0,
#         'saved': None}}]},
#     {'player': {'id': 191971,
#       'name': 'Jay Stansfield',
#       'photo': 'https://media.api-sports.io/football/players/191971.png'},
#      'statistics': [{'games': {'minutes': None,
#         'number': 65,
#         'position': 'F',
#         'rating': None,
#         'captain': False,
#         'substitute': True},
#        'offsides': None,
#        'shots': {'total': None, 'on': None},
#        'goals': {'total': None, 'conceded': 0, 'assists': None, 'saves': None},
#        'passes': {'total': None, 'key': None, 'accuracy': None},
#        'tackles': {'total': None, 'blocks': None, 'interceptions': None},
#        'duels': {'total': None, 'won': None},
#        'dribbles': {'attempts': None, 'success': None, 'past': None},
#        'fouls': {'drawn': None, 'committed': None},
#        'cards': {'yellow': 0, 'red': 0},
#        'penalty': {'won': None,
#         'commited': None,
#         'scored': 0,
#         'missed': 0,
#         'saved': None}}]}]},
#   {'team': {'id': 40,
#     'name': 'Liverpool',
#     'logo': 'https://media.api-sports.io/football/teams/40.png',
#     'update': '2023-05-30T04:11:35+00:00'},
#    'players': [{'player': {'id': 280,
#       'name': 'Alisson',
#       'photo': 'https://media.api-sports.io/football/players/280.png'},
#      'statistics': [{'games': {'minutes': 90,
#         'number': 1,
#         'position': 'G',
#         'rating': '6.2',
#         'captain': False,
#         'substitute': False},
#        'offsides': None,
#        'shots': {'total': None, 'on': None},
#        'goals': {'total': None, 'conceded': 2, 'assists': None, 'saves': 1},
#        'passes': {'total': 29, 'key': None, 'accuracy': '22'},
#        'tackles': {'total': None, 'blocks': None, 'interceptions': None},
#        'duels': {'total': None, 'won': None},
#        'dribbles': {'attempts': None, 'success': None, 'past': None},
#        'fouls': {'drawn': None, 'committed': None},
#        'cards': {'yellow': 0, 'red': 0},
#        'penalty': {'won': None,
#         'commited': None,
#         'scored': 0,
#         'missed': 0,
#         'saved': 0}}]},
#     {'player': {'id': 283,
#       'name': 'Trent Alexander-Arnold',
#       'photo': 'https://media.api-sports.io/football/players/283.png'},
#      'statistics': [{'games': {'minutes': 90,
#         'number': 66,
#         'position': 'D',
#         'rating': '6.9',
#         'captain': False,
#         'substitute': False},
#        'offsides': None,
#        'shots': {'total': None, 'on': None},
#        'goals': {'total': None, 'conceded': 0, 'assists': None, 'saves': None},
#        'passes': {'total': 61, 'key': 1, 'accuracy': '36'},
#        'tackles': {'total': 2, 'blocks': None, 'interceptions': 1},
#        'duels': {'total': 5, 'won': 2},
#        'dribbles': {'attempts': None, 'success': None, 'past': None},
#        'fouls': {'drawn': None, 'committed': 2},
#        'cards': {'yellow': 0, 'red': 0},
#        'penalty': {'won': None,
#         'commited': None,
#         'scored': 0,
#         'missed': 0,
#         'saved': None}}]},
#     {'player': {'id': 286,
#       'name': 'Joël Matip',
#       'photo': 'https://media.api-sports.io/football/players/286.png'},
#      'statistics': [{'games': {'minutes': 90,
#         'number': 32,
#         'position': 'D',
#         'rating': '6.6',
#         'captain': False,
#         'substitute': False},
#        'offsides': None,
#        'shots': {'total': None, 'on': None},
#        'goals': {'total': None, 'conceded': 0, 'assists': None, 'saves': None},
#        'passes': {'total': 93, 'key': None, 'accuracy': '79'},
#        'tackles': {'total': 3, 'blocks': 1, 'interceptions': 2},
#        'duels': {'total': 13, 'won': 5},
#        'dribbles': {'attempts': 3, 'success': 1, 'past': 1},
#        'fouls': {'drawn': 1, 'committed': None},
#        'cards': {'yellow': 0, 'red': 0},
#        'penalty': {'won': None,
#         'commited': None,
#         'scored': 0,
#         'missed': 0,
#         'saved': None}}]},
#     {'player': {'id': 290,
#       'name': 'Virgil van Dijk',
#       'photo': 'https://media.api-sports.io/football/players/290.png'},
#      'statistics': [{'games': {'minutes': 90,
#         'number': 4,
#         'position': 'M',
#         'rating': '6.5',
#         'captain': False,
#         'substitute': False},
#        'offsides': None,
#        'shots': {'total': None, 'on': None},
#        'goals': {'total': None, 'conceded': 0, 'assists': None, 'saves': None},
#        'passes': {'total': 95, 'key': None, 'accuracy': '79'},
#        'tackles': {'total': 2, 'blocks': None, 'interceptions': None},
#        'duels': {'total': 7, 'won': 5},
#        'dribbles': {'attempts': None, 'success': None, 'past': 1},
#        'fouls': {'drawn': None, 'committed': 1},
#        'cards': {'yellow': 0, 'red': 0},
#        'penalty': {'won': None,
#         'commited': 1,
#         'scored': 0,
#         'missed': 0,
#         'saved': None}}]},
#     {'player': {'id': 289,
#       'name': 'Andrew Robertson',
#       'photo': 'https://media.api-sports.io/football/players/289.png'},
#      'statistics': [{'games': {'minutes': 90,
#         'number': 26,
#         'position': 'D',
#         'rating': '6.5',
#         'captain': False,
#         'substitute': False},
#        'offsides': 1,
#        'shots': {'total': None, 'on': None},
#        'goals': {'total': None, 'conceded': 0, 'assists': None, 'saves': None},
#        'passes': {'total': 58, 'key': None, 'accuracy': '43'},
#        'tackles': {'total': 2, 'blocks': 1, 'interceptions': None},
#        'duels': {'total': 14, 'won': 6},
#        'dribbles': {'attempts': 3, 'success': None, 'past': None},
#        'fouls': {'drawn': 1, 'committed': 2},
#        'cards': {'yellow': 0, 'red': 0},
#        'penalty': {'won': None,
#         'commited': None,
#         'scored': 0,
#         'missed': 0,
#         'saved': None}}]},
#     {'player': {'id': 292,
#       'name': 'Jordan Henderson',
#       'photo': 'https://media.api-sports.io/football/players/292.png'},
#      'statistics': [{'games': {'minutes': 90,
#         'number': 14,
#         'position': 'M',
#         'rating': '7.2',
#         'captain': True,
#         'substitute': False},
#        'offsides': None,
#        'shots': {'total': 1, 'on': None},
#        'goals': {'total': None, 'conceded': 0, 'assists': None, 'saves': None},
#        'passes': {'total': 63, 'key': 2, 'accuracy': '45'},
#        'tackles': {'total': None, 'blocks': None, 'interceptions': 1},
#        'duels': {'total': 1, 'won': None},
#        'dribbles': {'attempts': None, 'success': None, 'past': None},
#        'fouls': {'drawn': None, 'committed': 1},
#        'cards': {'yellow': 0, 'red': 0},
#        'penalty': {'won': None,
#         'commited': None,
#         'scored': 0,
#         'missed': 0,
#         'saved': None}}]},
#     {'player': {'id': 299,
#       'name': 'Fabinho',
#       'photo': 'https://media.api-sports.io/football/players/299.png'},
#      'statistics': [{'games': {'minutes': 59,
#         'number': 3,
#         'position': 'D',
#         'rating': '6.9',
#         'captain': False,
#         'substitute': False},
#        'offsides': None,
#        'shots': {'total': None, 'on': None},
#        'goals': {'total': None, 'conceded': 0, 'assists': None, 'saves': None},
#        'passes': {'total': 36, 'key': None, 'accuracy': '29'},
#        'tackles': {'total': 1, 'blocks': 1, 'interceptions': 1},
#        'duels': {'total': 3, 'won': 2},
#        'dribbles': {'attempts': None, 'success': None, 'past': None},
#        'fouls': {'drawn': 1, 'committed': None},
#        'cards': {'yellow': 0, 'red': 0},
#        'penalty': {'won': None,
#         'commited': None,
#         'scored': 0,
#         'missed': 0,
#         'saved': None}}]},
#     {'player': {'id': 507,
#       'name': 'Thiago Alcântara',
#       'photo': 'https://media.api-sports.io/football/players/507.png'},
#      'statistics': [{'games': {'minutes': 51,
#         'number': 6,
#         'position': 'M',
#         'rating': '6.9',
#         'captain': False,
#         'substitute': False},
#        'offsides': None,
#        'shots': {'total': None, 'on': None},
#        'goals': {'total': None, 'conceded': 0, 'assists': None, 'saves': None},
#        'passes': {'total': 54, 'key': 1, 'accuracy': '47'},
#        'tackles': {'total': None, 'blocks': None, 'interceptions': 1},
#        'duels': {'total': 9, 'won': 3},
#        'dribbles': {'attempts': 1, 'success': None, 'past': 1},
#        'fouls': {'drawn': 1, 'committed': None},
#        'cards': {'yellow': 0, 'red': 0},
#        'penalty': {'won': None,
#         'commited': None,
#         'scored': 0,
#         'missed': 0,
#         'saved': None}}]},
#     {'player': {'id': 306,
#       'name': 'Mohamed Salah',
#       'photo': 'https://media.api-sports.io/football/players/306.png'},
#      'statistics': [{'games': {'minutes': 90,
#         'number': 11,
#         'position': 'F',
#         'rating': '7.6',
#         'captain': False,
#         'substitute': False},
#        'offsides': 2,
#        'shots': {'total': 2, 'on': 1},
#        'goals': {'total': 1, 'conceded': 0, 'assists': None, 'saves': None},
#        'passes': {'total': 32, 'key': 1, 'accuracy': '22'},
#        'tackles': {'total': None, 'blocks': None, 'interceptions': 1},
#        'duels': {'total': 8, 'won': 2},
#        'dribbles': {'attempts': 5, 'success': 2, 'past': 2},
#        'fouls': {'drawn': None, 'committed': None},
#        'cards': {'yellow': 0, 'red': 0},
#        'penalty': {'won': None,
#         'commited': None,
#         'scored': 0,
#         'missed': 0,
#         'saved': None}}]},
#     {'player': {'id': 302,
#       'name': 'Roberto Firmino',
#       'photo': 'https://media.api-sports.io/football/players/302.png'},
#      'statistics': [{'games': {'minutes': 51,
#         'number': 9,
#         'position': 'F',
#         'rating': '6.7',
#         'captain': False,
#         'substitute': False},
#        'offsides': None,
#        'shots': {'total': None, 'on': None},
#        'goals': {'total': None, 'conceded': 0, 'assists': None, 'saves': None},
#        'passes': {'total': 24, 'key': None, 'accuracy': '18'},
#        'tackles': {'total': 1, 'blocks': 1, 'interceptions': None},
#        'duels': {'total': 4, 'won': 2},
#        'dribbles': {'attempts': None, 'success': None, 'past': None},
#        'fouls': {'drawn': None, 'committed': None},
#        'cards': {'yellow': 0, 'red': 0},
#        'penalty': {'won': None,
#         'commited': None,
#         'scored': 0,
#         'missed': 0,
#         'saved': None}}]},
#     {'player': {'id': 2489,
#       'name': 'Luis Díaz',
#       'photo': 'https://media.api-sports.io/football/players/2489.png'},
#      'statistics': [{'games': {'minutes': 78,
#         'number': 23,
#         'position': 'F',
#         'rating': '6.7',
#         'captain': False,
#         'substitute': False},
#        'offsides': None,
#        'shots': {'total': 1, 'on': None},
#        'goals': {'total': None, 'conceded': 0, 'assists': None, 'saves': None},
#        'passes': {'total': 23, 'key': None, 'accuracy': '19'},
#        'tackles': {'total': None, 'blocks': None, 'interceptions': None},
#        'duels': {'total': 10, 'won': 3},
#        'dribbles': {'attempts': 1, 'success': 1, 'past': None},
#        'fouls': {'drawn': 2, 'committed': 1},
#        'cards': {'yellow': 0, 'red': 0},
#        'penalty': {'won': None,
#         'commited': None,
#         'scored': 0,
#         'missed': 0,
#         'saved': None}}]},
#     {'player': {'id': 18812,
#       'name': 'Adrián',
#       'photo': 'https://media.api-sports.io/football/players/18812.png'},
#      'statistics': [{'games': {'minutes': None,
#         'number': 13,
#         'position': 'G',
#         'rating': None,
#         'captain': False,
#         'substitute': True},
#        'offsides': None,
#        'shots': {'total': None, 'on': None},
#        'goals': {'total': None, 'conceded': 0, 'assists': None, 'saves': None},
#        'passes': {'total': None, 'key': None, 'accuracy': None},
#        'tackles': {'total': None, 'blocks': None, 'interceptions': None},
#        'duels': {'total': None, 'won': None},
#        'dribbles': {'attempts': None, 'success': None, 'past': None},
#        'fouls': {'drawn': None, 'committed': None},
#        'cards': {'yellow': 0, 'red': 0},
#        'penalty': {'won': None,
#         'commited': None,
#         'scored': 0,
#         'missed': 0,
#         'saved': None}}]},
#     {'player': {'id': 284,
#       'name': 'Joe Gomez',
#       'photo': 'https://media.api-sports.io/football/players/284.png'},
#      'statistics': [{'games': {'minutes': None,
#         'number': 2,
#         'position': 'D',
#         'rating': None,
#         'captain': False,
#         'substitute': True},
#        'offsides': None,
#        'shots': {'total': None, 'on': None},
#        'goals': {'total': None, 'conceded': 0, 'assists': None, 'saves': None},
#        'passes': {'total': None, 'key': None, 'accuracy': None},
#        'tackles': {'total': None, 'blocks': None, 'interceptions': None},
#        'duels': {'total': None, 'won': None},
#        'dribbles': {'attempts': None, 'success': None, 'past': None},
#        'fouls': {'drawn': None, 'committed': None},
#        'cards': {'yellow': 0, 'red': 0},
#        'penalty': {'won': None,
#         'commited': None,
#         'scored': 0,
#         'missed': 0,
#         'saved': None}}]},
#     {'player': {'id': 36922,
#       'name': 'Sepp van den Berg',
#       'photo': 'https://media.api-sports.io/football/players/36922.png'},
#      'statistics': [{'games': {'minutes': None,
#         'number': 72,
#         'position': 'D',
#         'rating': None,
#         'captain': False,
#         'substitute': True},
#        'offsides': None,
#        'shots': {'total': None, 'on': None},
#        'goals': {'total': None, 'conceded': 0, 'assists': None, 'saves': None},
#        'passes': {'total': None, 'key': None, 'accuracy': None},
#        'tackles': {'total': None, 'blocks': None, 'interceptions': None},
#        'duels': {'total': None, 'won': None},
#        'dribbles': {'attempts': None, 'success': None, 'past': None},
#        'fouls': {'drawn': None, 'committed': None},
#        'cards': {'yellow': 0, 'red': 0},
#        'penalty': {'won': None,
#         'commited': None,
#         'scored': 0,
#         'missed': 0,
#         'saved': None}}]},
#     {'player': {'id': 284366,
#       'name': 'Luke Chambers',
#       'photo': 'https://media.api-sports.io/football/players/284366.png'},
#      'statistics': [{'games': {'minutes': None,
#         'number': 88,
#         'position': 'D',
#         'rating': None,
#         'captain': False,
#         'substitute': True},
#        'offsides': None,
#        'shots': {'total': None, 'on': None},
#        'goals': {'total': None, 'conceded': 0, 'assists': None, 'saves': None},
#        'passes': {'total': None, 'key': None, 'accuracy': None},
#        'tackles': {'total': None, 'blocks': None, 'interceptions': None},
#        'duels': {'total': None, 'won': None},
#        'dribbles': {'attempts': None, 'success': None, 'past': None},
#        'fouls': {'drawn': None, 'committed': None},
#        'cards': {'yellow': 0, 'red': 0},
#        'penalty': {'won': None,
#         'commited': None,
#         'scored': 0,
#         'missed': 0,
#         'saved': None}}]},
#     {'player': {'id': 310187,
#       'name': 'Stefan Bajčetić',
#       'photo': 'https://media.api-sports.io/football/players/310187.png'},
#      'statistics': [{'games': {'minutes': None,
#         'number': 43,
#         'position': 'D',
#         'rating': None,
#         'captain': False,
#         'substitute': True},
#        'offsides': None,
#        'shots': {'total': None, 'on': None},
#        'goals': {'total': None, 'conceded': 0, 'assists': None, 'saves': None},
#        'passes': {'total': None, 'key': None, 'accuracy': None},
#        'tackles': {'total': None, 'blocks': None, 'interceptions': None},
#        'duels': {'total': None, 'won': None},
#        'dribbles': {'attempts': None, 'success': None, 'past': None},
#        'fouls': {'drawn': None, 'committed': None},
#        'cards': {'yellow': 0, 'red': 0},
#        'penalty': {'won': None,
#         'commited': None,
#         'scored': 0,
#         'missed': 0,
#         'saved': None}}]},
#     {'player': {'id': 153066,
#       'name': 'Fabio Carvalho',
#       'photo': 'https://media.api-sports.io/football/players/153066.png'},
#      'statistics': [{'games': {'minutes': 12,
#         'number': 28,
#         'position': 'M',
#         'rating': '6.6',
#         'captain': False,
#         'substitute': True},
#        'offsides': None,
#        'shots': {'total': 1, 'on': None},
#        'goals': {'total': None, 'conceded': 0, 'assists': None, 'saves': None},
#        'passes': {'total': 2, 'key': None, 'accuracy': '2'},
#        'tackles': {'total': None, 'blocks': None, 'interceptions': 2},
#        'duels': {'total': 4, 'won': 1},
#        'dribbles': {'attempts': None, 'success': None, 'past': None},
#        'fouls': {'drawn': None, 'committed': 2},
#        'cards': {'yellow': 0, 'red': 0},
#        'penalty': {'won': None,
#         'commited': None,
#         'scored': 0,
#         'missed': 0,
#         'saved': None}}]},
#     {'player': {'id': 19035,
#       'name': 'Harvey Elliott',
#       'photo': 'https://media.api-sports.io/football/players/19035.png'},
#      'statistics': [{'games': {'minutes': 39,
#         'number': 19,
#         'position': 'M',
#         'rating': '6.2',
#         'captain': False,
#         'substitute': True},
#        'offsides': None,
#        'shots': {'total': None, 'on': None},
#        'goals': {'total': None, 'conceded': 0, 'assists': None, 'saves': None},
#        'passes': {'total': 20, 'key': 1, 'accuracy': '17'},
#        'tackles': {'total': None, 'blocks': None, 'interceptions': 1},
#        'duels': {'total': 5, 'won': 1},
#        'dribbles': {'attempts': 1, 'success': None, 'past': None},
#        'fouls': {'drawn': 1, 'committed': None},
#        'cards': {'yellow': 0, 'red': 0},
#        'penalty': {'won': None,
#         'commited': None,
#         'scored': 0,
#         'missed': 0,
#         'saved': None}}]},
#     {'player': {'id': 296,
#       'name': 'James Milner',
#       'photo': 'https://media.api-sports.io/football/players/296.png'},
#      'statistics': [{'games': {'minutes': 31,
#         'number': 7,
#         'position': 'M',
#         'rating': '6.2',
#         'captain': False,
#         'substitute': True},
#        'offsides': None,
#        'shots': {'total': None, 'on': None},
#        'goals': {'total': None, 'conceded': 0, 'assists': None, 'saves': None},
#        'passes': {'total': 16, 'key': None, 'accuracy': '10'},
#        'tackles': {'total': None, 'blocks': None, 'interceptions': None},
#        'duels': {'total': 6, 'won': None},
#        'dribbles': {'attempts': None, 'success': None, 'past': None},
#        'fouls': {'drawn': None, 'committed': None},
#        'cards': {'yellow': 0, 'red': 0},
#        'penalty': {'won': None,
#         'commited': None,
#         'scored': 0,
#         'missed': 0,
#         'saved': None}}]},
#     {'player': {'id': 51617,
#       'name': 'Darwin Núñez',
#       'photo': 'https://media.api-sports.io/football/players/51617.png'},
#      'statistics': [{'games': {'minutes': 39,
#         'number': 27,
#         'position': 'F',
#         'rating': '7.5',
#         'captain': False,
#         'substitute': True},
#        'offsides': 1,
#        'shots': {'total': 4, 'on': 3},
#        'goals': {'total': 1, 'conceded': 0, 'assists': 1, 'saves': None},
#        'passes': {'total': 6, 'key': 2, 'accuracy': '5'},
#        'tackles': {'total': None, 'blocks': None, 'interceptions': None},
#        'duels': {'total': 7, 'won': 3},
#        'dribbles': {'attempts': 1, 'success': None, 'past': None},
#        'fouls': {'drawn': None, 'committed': None},
#        'cards': {'yellow': 0, 'red': 0},
#        'penalty': {'won': None,
#         'commited': None,
#         'scored': 0,
#         'missed': 0,
#         'saved': None}}]}]}]}

# %%
pd.json_normalize(pd.json_normalize(player_stat_away[867947].json()['response'])['players'][1])
# Out:
#                                            statistics  player.id  \
# 0   [{'games': {'minutes': 90, 'number': 1, 'posit...        280
# 1   [{'games': {'minutes': 90, 'number': 66, 'posi...        283
# 2   [{'games': {'minutes': 90, 'number': 32, 'posi...        286
# 3   [{'games': {'minutes': 90, 'number': 4, 'posit...        290
# 4   [{'games': {'minutes': 90, 'number': 26, 'posi...        289
# 5   [{'games': {'minutes': 90, 'number': 14, 'posi...        292
# 6   [{'games': {'minutes': 59, 'number': 3, 'posit...        299
# 7   [{'games': {'minutes': 51, 'number': 6, 'posit...        507
# 8   [{'games': {'minutes': 90, 'number': 11, 'posi...        306
# 9   [{'games': {'minutes': 51, 'number': 9, 'posit...        302
# 10  [{'games': {'minutes': 78, 'number': 23, 'posi...       2489
# 11  [{'games': {'minutes': None, 'number': 13, 'po...      18812
# 12  [{'games': {'minutes': None, 'number': 2, 'pos...        284
# 13  [{'games': {'minutes': None, 'number': 72, 'po...      36922
# 14  [{'games': {'minutes': None, 'number': 88, 'po...     284366
# 15  [{'games': {'minutes': None, 'number': 43, 'po...     310187
# 16  [{'games': {'minutes': 12, 'number': 28, 'posi...     153066
# 17  [{'games': {'minutes': 39, 'number': 19, 'posi...      19035
# 18  [{'games': {'minutes': 31, 'number': 7, 'posit...        296
# 19  [{'games': {'minutes': 39, 'number': 27, 'posi...      51617
#
#                player.name                                       player.photo
# 0                  Alisson  https://media.api-sports.io/football/players/2...
# 1   Trent Alexander-Arnold  https://media.api-sports.io/football/players/2...
# 2               Joël Matip  https://media.api-sports.io/football/players/2...
# 3          Virgil van Dijk  https://media.api-sports.io/football/players/2...
# 4         Andrew Robertson  https://media.api-sports.io/football/players/2...
# 5         Jordan Henderson  https://media.api-sports.io/football/players/2...
# 6                  Fabinho  https://media.api-sports.io/football/players/2...
# 7         Thiago Alcântara  https://media.api-sports.io/football/players/5...
# 8            Mohamed Salah  https://media.api-sports.io/football/players/3...
# 9          Roberto Firmino  https://media.api-sports.io/football/players/3...
# 10               Luis Díaz  https://media.api-sports.io/football/players/2...
# 11                  Adrián  https://media.api-sports.io/football/players/1...
# 12               Joe Gomez  https://media.api-sports.io/football/players/2...
# 13       Sepp van den Berg  https://media.api-sports.io/football/players/3...
# 14           Luke Chambers  https://media.api-sports.io/football/players/2...
# 15         Stefan Bajčetić  https://media.api-sports.io/football/players/3...
# 16          Fabio Carvalho  https://media.api-sports.io/football/players/1...
# 17          Harvey Elliott  https://media.api-sports.io/football/players/1...
# 18            James Milner  https://media.api-sports.io/football/players/2...
# 19            Darwin Núñez  https://media.api-sports.io/football/players/5...

# %%
# Example to get each players match statistic for a given team:
# Multiple levels to wrangle json data
player_stats_home = dict()
player_stats_away = dict()
#For Home Games, we can get the first 1st players statistics row and 2nd for away fixtures
for k,v in player_stat_home.items():
    print("Checking for Home team")
    try:
        print(pd.json_normalize(v.json()['response'])['players'])
        player_stats_home[k] = pd.concat([pd.json_normalize(pd.json_normalize(v.json()['response'])['players'][0])[['player.id','player.name']],pd.json_normalize(pd.json_normalize(pd.json_normalize(pd.json_normalize(v.json()['response'])['players'][0])['statistics']).rename(columns = {0:"player_stats"})['player_stats'])],axis = 1)
    except:
        print("problematic fixture id: ", k)
        continue
# Get 2nd for Away fixtures
for k,v in player_stat_away.items():
    print("Checking for Away team")
    try:
        print(pd.json_normalize(v.json()['response'])['players'])
        player_stats_away[k] = pd.concat([pd.json_normalize(pd.json_normalize(v.json()['response'])['players'][1])[['player.id','player.name']],pd.json_normalize(pd.json_normalize(pd.json_normalize(pd.json_normalize(v.json()['response'])['players'][1])['statistics']).rename(columns = {0:"player_stats"})['player_stats'])],axis = 1)
    except:
        print("problematic fixture id: ", k)
        continue
# Out:
# Checking for Home team
# 0    [{'player': {'id': 280, 'name': 'Alisson', 'ph...
# 1    [{'player': {'id': 18835, 'name': 'Vicente Gua...
# Name: players, dtype: object
# Checking for Home team
# 0    [{'player': {'id': 280, 'name': 'Alisson', 'ph...
# 1    [{'player': {'id': 18860, 'name': 'Mark Traver...
# Name: players, dtype: object
# Checking for Home team
# 0    [{'player': {'id': 280, 'name': 'Alisson', 'ph...
# 1    [{'player': {'id': 18911, 'name': 'Nick Pope',...
# Name: players, dtype: object
# Checking for Home team
# 0    [{'player': {'id': 280, 'name': 'Alisson', 'ph...
# 1    [{'player': {'id': 1590, 'name': 'José Sá', 'p...
# Name: players, dtype: object
# Checking for Home team
# 0    [{'player': {'id': 280, 'name': 'Alisson', 'ph...
# 1    [{'player': {'id': 18959, 'name': 'Robert Sánc...
# Name: players, dtype: object
# Checking for Home team
# 0    [{'player': {'id': 280, 'name': 'Alisson', 'ph...
# 1    [{'player': {'id': 617, 'name': 'Ederson', 'ph...
# Name: players, dtype: object
# Checking for Home team
# 0    [{'player': {'id': 280, 'name': 'Alisson', 'ph...
# 1    [{'player': {'id': 2997, 'name': 'Łukasz Fabia...
# Name: players, dtype: object
# Checking for Home team
# 0    [{'player': {'id': 280, 'name': 'Alisson', 'ph...
# 1    [{'player': {'id': 20619, 'name': 'Illan Mesli...
# Name: players, dtype: object
# Checking for Home team
# 0    [{'player': {'id': 280, 'name': 'Alisson', 'ph...
# 1    [{'player': {'id': 105971, 'name': 'Gavin Bazu...
# Name: players, dtype: object
# Checking for Home team
# 0    [{'player': {'id': 280, 'name': 'Alisson', 'ph...
# 1    [{'player': {'id': 18146, 'name': 'Danny Ward'...
# Name: players, dtype: object
# Checking for Home team
# 0    [{'player': {'id': 280, 'name': 'Alisson', 'ph...
# 1    [{'player': {'id': 2273, 'name': 'Kepa Arrizab...
# Name: players, dtype: object
# Checking for Home team
# 0    [{'player': {'id': 280, 'name': 'Alisson', 'ph...
# 1    [{'player': {'id': 2932, 'name': 'Jordan Pickf...
# Name: players, dtype: object
# Checking for Home team
# 0    [{'player': {'id': 280, 'name': 'Alisson', 'ph...
# 1    [{'player': {'id': 882, 'name': 'David De Gea'...
# Name: players, dtype: object
# Checking for Home team
# 0    [{'player': {'id': 280, 'name': 'Alisson', 'ph...
# 1    [{'player': {'id': 1438, 'name': 'Bernd Leno',...
# Name: players, dtype: object
# Checking for Home team
# 0    [{'player': {'id': 280, 'name': 'Alisson', 'ph...
# 1    [{'player': {'id': 20355, 'name': 'Aaron Ramsd...
# Name: players, dtype: object
# Checking for Home team
# 0    [{'player': {'id': 280, 'name': 'Alisson', 'ph...
# 1    [{'player': {'id': 731, 'name': 'Keylor Navas'...
# Name: players, dtype: object
# Checking for Home team
# 0    [{'player': {'id': 280, 'name': 'Alisson', 'ph...
# 1    [{'player': {'id': 18932, 'name': 'Fraser Fors...
# Name: players, dtype: object
# Checking for Home team
# 0    [{'player': {'id': 280, 'name': 'Alisson', 'ph...
# 1    [{'player': {'id': 19465, 'name': 'David Raya'...
# Name: players, dtype: object
# Checking for Home team
# 0    [{'player': {'id': 280, 'name': 'Alisson', 'ph...
# 1    [{'player': {'id': 19599, 'name': 'Emiliano Ma...
# Name: players, dtype: object
# Checking for Away team
# 0    [{'player': {'id': 19657, 'name': 'Marek Rodák...
# 1    [{'player': {'id': 280, 'name': 'Alisson', 'ph...
# Name: players, dtype: object
# Checking for Away team
# 0    [{'player': {'id': 882, 'name': 'David De Gea'...
# 1    [{'player': {'id': 280, 'name': 'Alisson', 'ph...
# Name: players, dtype: object
# Checking for Away team
# 0    [{'player': {'id': 2932, 'name': 'Jordan Pickf...
# 1    [{'player': {'id': 280, 'name': 'Alisson', 'ph...
# Name: players, dtype: object
# Checking for Away team
# 0    [{'player': {'id': 2273, 'name': 'Kepa Arrizab...
# 1    [{'player': {'id': 280, 'name': 'Alisson', 'ph...
# Name: players, dtype: object
# Checking for Away team
# 0    [{'player': {'id': 20355, 'name': 'Aaron Ramsd...
# 1    [{'player': {'id': 280, 'name': 'Alisson', 'ph...
# Name: players, dtype: object
# Checking for Away team
# 0    [{'player': {'id': 19088, 'name': 'Dean Hender...
# 1    [{'player': {'id': 280, 'name': 'Alisson', 'ph...
# Name: players, dtype: object
# Checking for Away team
# 0    [{'player': {'id': 159, 'name': 'Hugo Lloris',...
# 1    [{'player': {'id': 280, 'name': 'Alisson', 'ph...
# Name: players, dtype: object
# Checking for Away team
# 0    [{'player': {'id': 766, 'name': 'Robin Olsen',...
# 1    [{'player': {'id': 280, 'name': 'Alisson', 'ph...
# Name: players, dtype: object
# Checking for Away team
# 0    [{'player': {'id': 19465, 'name': 'David Raya'...
# 1    [{'player': {'id': 280, 'name': 'Alisson', 'ph...
# Name: players, dtype: object
# Checking for Away team
# 0    [{'player': {'id': 18959, 'name': 'Robert Sánc...
# 1    [{'player': {'id': 280, 'name': 'Alisson', 'ph...
# Name: players, dtype: object
# Checking for Away team
# 0    [{'player': {'id': 1590, 'name': 'José Sá', 'p...
# 1    [{'player': {'id': 280, 'name': 'Alisson', 'ph...
# Name: players, dtype: object
# Checking for Away team
# 0    [{'player': {'id': 18911, 'name': 'Nick Pope',...
# 1    [{'player': {'id': 280, 'name': 'Alisson', 'ph...
# Name: players, dtype: object
# Checking for Away team
# 0    [{'player': {'id': 18835, 'name': 'Vicente Gua...
# 1    [{'player': {'id': 280, 'name': 'Alisson', 'ph...
# Name: players, dtype: object
# Checking for Away team
# 0    [{'player': {'id': 912, 'name': 'Neto', 'photo...
# 1    [{'player': {'id': 280, 'name': 'Alisson', 'ph...
# Name: players, dtype: object
# Checking for Away team
# 0    [{'player': {'id': 617, 'name': 'Ederson', 'ph...
# 1    [{'player': {'id': 280, 'name': 'Alisson', 'ph...
# Name: players, dtype: object
# Checking for Away team
# 0    [{'player': {'id': 20619, 'name': 'Illan Mesli...
# 1    [{'player': {'id': 280, 'name': 'Alisson', 'ph...
# Name: players, dtype: object
# Checking for Away team
# 0    [{'player': {'id': 2997, 'name': 'Łukasz Fabia...
# 1    [{'player': {'id': 280, 'name': 'Alisson', 'ph...
# Name: players, dtype: object
# Checking for Away team
# 0    [{'player': {'id': 17736, 'name': 'Daniel Iver...
# 1    [{'player': {'id': 280, 'name': 'Alisson', 'ph...
# Name: players, dtype: object
# Checking for Away team
# 0    [{'player': {'id': 18935, 'name': 'Alex McCart...
# 1    [{'player': {'id': 281, 'name': 'Caoimhin Kell...
# Name: players, dtype: object

# %%
for k,v in player_stats_home.items():
    v['fixture'] = k
for k,v in player_stats_away.items():
    v['fixture'] = k

# %%
liverpool_player_stats = pd.concat(player_stats_home.values(),axis=0)
liverpool_player_stats = pd.concat([liverpool_player_stats] + list(player_stats_away.values()),axis = 0)
liverpool_player_stats.shape
# Out:
# /var/folders/pc/0lfpljp976ddkk6w26_s9pr80000gn/T/ipykernel_1333/644054684.py:1: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   liverpool_player_stats = pd.concat(player_stats_home.values(),axis=0)
# /var/folders/pc/0lfpljp976ddkk6w26_s9pr80000gn/T/ipykernel_1333/644054684.py:2: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   liverpool_player_stats = pd.concat([liverpool_player_stats] + list(player_stats_away.values()),axis = 0)
# (760, 36)

# %%
liverpool_player_stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 760 entries, 0 to 19
# Data columns (total 36 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   player.id              760 non-null    int64
#  1   player.name            760 non-null    object
#  2   offsides               70 non-null     float64
#  3   games.minutes          582 non-null    float64
#  4   games.number           760 non-null    int64
#  5   games.position         760 non-null    object
#  6   games.rating           573 non-null    object
#  7   games.captain          760 non-null    bool
#  8   games.substitute       760 non-null    bool
#  9   shots.total            243 non-null    float64
#  10  shots.on               149 non-null    float64
#  11  goals.total            58 non-null     float64
#  12  goals.conceded         760 non-null    int64
#  13  goals.assists          49 non-null     float64
#  14  goals.saves            37 non-null     float64
#  15  passes.total           578 non-null    float64
#  16  passes.key             268 non-null    float64
#  17  passes.accuracy        574 non-null    object
#  18  tackles.total          309 non-null    float64
#  19  tackles.blocks         66 non-null     float64
#  20  tackles.interceptions  221 non-null    float64
#  21  duels.total            532 non-null    float64
#  22  duels.won              475 non-null    float64
#  23  dribbles.attempts      280 non-null    float64
#  24  dribbles.success       196 non-null    float64
#  25  dribbles.past          235 non-null    float64
#  26  fouls.drawn            207 non-null    float64
#  27  fouls.committed        270 non-null    float64
#  28  cards.yellow           760 non-null    int64
#  29  cards.red              760 non-null    int64
#  30  penalty.won            3 non-null      float64
#  31  penalty.commited       4 non-null      float64
#  32  penalty.scored         760 non-null    int64
#  33  penalty.missed         760 non-null    int64
#  34  penalty.saved          38 non-null     float64
#  35  fixture                760 non-null    int64
# dtypes: bool(2), float64(22), int64(8), object(4)
# memory usage: 209.3+ KB

# %%
liverpool_player_stats.head()
# Out:
#    player.id             player.name  offsides  games.minutes  games.number  \
# 0        280                 Alisson       NaN           90.0             1
# 1        283  Trent Alexander-Arnold       1.0           90.0            66
# 2     127472      Nathaniel Phillips       NaN           63.0            47
# 3        290         Virgil van Dijk       NaN           90.0             4
# 4        289        Andrew Robertson       NaN           63.0            26
#
#   games.position games.rating  games.captain  games.substitute  shots.total  \
# 0              G          6.7          False             False          NaN
# 1              D            8          False             False          1.0
# 2              D          7.2          False             False          NaN
# 3              D          6.9          False             False          1.0
# 4              D          6.3          False             False          NaN
#
#    shots.on  goals.total  goals.conceded  goals.assists  goals.saves  \
# 0       NaN          NaN               1            NaN          2.0
# 1       NaN          NaN               0            NaN          NaN
# 2       NaN          NaN               0            NaN          NaN
# 3       NaN          NaN               0            NaN          NaN
# 4       NaN          NaN               0            NaN          NaN
#
#    passes.total  passes.key passes.accuracy  tackles.total  tackles.blocks  \
# 0          28.0         NaN              24            NaN             NaN
# 1          94.0         5.0              74            1.0             NaN
# 2          79.0         NaN              68            2.0             NaN
# 3          80.0         NaN              72            NaN             NaN
# 4          55.0         NaN              45            NaN             NaN
#
#    tackles.interceptions  duels.total  duels.won  dribbles.attempts  \
# 0                    NaN          NaN        NaN                NaN
# 1                    1.0          5.0        2.0                NaN
# 2                    2.0          7.0        6.0                NaN
# 3                    NaN          NaN        NaN                NaN
# 4                    1.0          6.0        1.0                1.0
#
#    dribbles.success  dribbles.past  fouls.drawn  fouls.committed  \
# 0               NaN            NaN          NaN              NaN
# 1               NaN            3.0          NaN              NaN
# 2               NaN            NaN          NaN              1.0
# 3               NaN            NaN          NaN              NaN
# 4               NaN            1.0          NaN              NaN
#
#    cards.yellow  cards.red  penalty.won  penalty.commited  penalty.scored  \
# 0             0          0          NaN               NaN               0
# 1             0          0          NaN               NaN               0
# 2             0          0          NaN               NaN               0
# 3             0          0          NaN               NaN               0
# 4             0          0          NaN               NaN               0
#
#    penalty.missed  penalty.saved  fixture
# 0               0            0.0   867961
# 1               0            NaN   867961
# 2               0            NaN   867961
# 3               0            NaN   867961
# 4               0            NaN   867961

# %%
# Example summary
# Most Offside
# NA imputed w 0 makes sense for Offsides
liverpool_player_stats['offsides'].fillna(0,inplace=True)
most_offside = liverpool_player_stats.groupby(['player.name']).agg(mean_offside = ("offsides","mean"),mean_mins_played = ("games.minutes","sum")).sort_values("mean_offside",ascending = False)
most_offside[most_offside['mean_offside'] > 0]
# Out:
#                          mean_offside  mean_mins_played
# player.name
# Darwin Núñez                 0.586207            1698.0
# Mohamed Salah                0.578947            3294.0
# Cody Gakpo                   0.380952            1465.0
# Andrew Robertson             0.200000            2589.0
# Roberto Firmino              0.200000            1212.0
# Luis Díaz                    0.176471             997.0
# Diogo Jota                   0.136364            1137.0
# Trent Alexander-Arnold       0.131579            2940.0
# Virgil van Dijk              0.090909            2835.0
# Curtis Jones                 0.086957            1051.0
# Jordan Henderson             0.085714            2073.0
# Alex Oxlade-Chamberlain      0.076923             341.0
# Harvey Elliott               0.054054            1616.0
# Ibrahima Konaté              0.047619            1551.0
# Joël Matip                   0.034483            1093.0
# Joe Gomez                    0.030303            1471.0

# %%
liverpool_player_stats[(liverpool_player_stats['player.name'] == "Darwin Núñez") & (liverpool_player_stats['offsides'] >= 1)]
# Out:
#     player.id   player.name  offsides  games.minutes  games.number  \
# 10      51617  Darwin Núñez       1.0           89.0            27
# 19      51617  Darwin Núñez       1.0           18.0            27
# 19      51617  Darwin Núñez       1.0           27.0            27
# 10      51617  Darwin Núñez       1.0           65.0            27
# 19      51617  Darwin Núñez       1.0           39.0            27
# 10      51617  Darwin Núñez       5.0           90.0            27
# 9       51617  Darwin Núñez       2.0           88.0            27
# 9       51617  Darwin Núñez       2.0           90.0            27
# 9       51617  Darwin Núñez       1.0           90.0            27
# 10      51617  Darwin Núñez       2.0           66.0            27
#
#    games.position games.rating  games.captain  games.substitute  shots.total  \
# 10              F          7.5          False             False          3.0
# 19              F          6.6          False              True          2.0
# 19              F          6.9          False              True          1.0
# 10              F          6.2          False             False          1.0
# 19              F          7.5          False              True          4.0
# 10              F            7          False             False          2.0
# 9               F          5.6          False             False          6.0
# 9               F          6.3          False             False          2.0
# 9               F          6.7          False             False          4.0
# 10              F          6.6          False             False          1.0
#
#     shots.on  goals.total  goals.conceded  goals.assists  goals.saves  \
# 10       NaN          NaN               0            NaN          NaN
# 19       NaN          NaN               0            NaN          NaN
# 19       1.0          NaN               0            NaN          NaN
# 10       NaN          NaN               0            NaN          NaN
# 19       3.0          1.0               0            1.0          NaN
# 10       2.0          1.0               0            NaN          NaN
# 9        4.0          NaN               0            NaN          NaN
# 9        1.0          NaN               0            NaN          NaN
# 9        2.0          NaN               0            NaN          NaN
# 10       1.0          NaN               0            NaN          NaN
#
#     passes.total  passes.key passes.accuracy  tackles.total  tackles.blocks  \
# 10          23.0         3.0              15            1.0             NaN
# 19           1.0         1.0               1            NaN             NaN
# 19           6.0         1.0               4            2.0             NaN
# 10          11.0         1.0               9            NaN             NaN
# 19           6.0         2.0               5            NaN             NaN
# 10          10.0         NaN               7            NaN             NaN
# 9           12.0         1.0               4            NaN             NaN
# 9           12.0         NaN               7            NaN             NaN
# 9           13.0         1.0               7            NaN             NaN
# 10          11.0         NaN               8            1.0             NaN
#
#     tackles.interceptions  duels.total  duels.won  dribbles.attempts  \
# 10                    1.0         14.0        6.0                3.0
# 19                    NaN          4.0        2.0                1.0
# 19                    NaN          8.0        5.0                1.0
# 10                    NaN          6.0        1.0                NaN
# 19                    NaN          7.0        3.0                1.0
# 10                    NaN          9.0        2.0                NaN
# 9                     NaN          5.0        3.0                NaN
# 9                     NaN          8.0        3.0                2.0
# 9                     NaN          9.0        5.0                NaN
# 10                    NaN          8.0        3.0                1.0
#
#     dribbles.success  dribbles.past  fouls.drawn  fouls.committed  \
# 10               3.0            4.0          1.0              2.0
# 19               1.0            NaN          1.0              NaN
# 19               NaN            1.0          1.0              NaN
# 10               NaN            1.0          NaN              1.0
# 19               NaN            NaN          NaN              NaN
# 10               NaN            1.0          NaN              2.0
# 9                NaN            NaN          NaN              1.0
# 9                1.0            NaN          1.0              1.0
# 9                NaN            NaN          1.0              NaN
# 10               1.0            NaN          NaN              1.0
#
#     cards.yellow  cards.red  penalty.won  penalty.commited  penalty.scored  \
# 10             0          0          NaN               NaN               0
# 19             0          0          NaN               NaN               0
# 19             0          0          NaN               NaN               0
# 10             0          0          NaN               NaN               0
# 19             0          0          NaN               NaN               0
# 10             0          0          NaN               NaN               0
# 9              0          0          NaN               NaN               0
# 9              1          0          NaN               NaN               0
# 9              0          0          NaN               NaN               0
# 10             0          0          NaN               NaN               0
#
#     penalty.missed  penalty.saved  fixture
# 10               0            NaN   868012
# 19               0            NaN   868051
# 19               0            NaN   868152
# 10               0            NaN   868289
# 19               0            NaN   867947
# 10               0            NaN   868037
# 9                0            NaN   868107
# 9                0            NaN   868128
# 9                0            NaN   868165
# 10               0            NaN   868206

# %% [markdown]
# # Darwin and Salah are Offside a lot!

# %%
# Data looks good so far, Save for Future Use

# %% [markdown]
# # Next Steps:
# - Stratification: Need Player positions to find stats relevant to position/Event
