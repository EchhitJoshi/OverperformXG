# %%
import pandas as pd
import numpy as np
import sys

# %% [markdown]
# # Using API Football
# https://www.api-football.com

# %% [markdown]
# ![PYTHON LOGO](https://www.api-football.com/public/img/news/archi-beta.jpg)

# %% [markdown]
# Image: https://www.api-football.com/public/img/news/archi-beta.jpg <br>
# Overview: https://rapidapi.com/api-sports/api/api-football/tutorials/how-to-use-the-api-football-api-with-python
#
#
# # Primary team in focus: Liverpool

# %% [markdown]
# # Data Pulls

# %%
# API Key and Configs
import requests
headers = {
	"X-RapidAPI-Key": "64f82034damsh6dd2baeda9216d1p173668jsnddc6687707f5",
	"X-RapidAPI-Host": "api-football-v1.p.rapidapi.com"
}

# %%
# Countries
country_url = "https://api-football-vi.p.rapidapi.com/v2/countries"
country_dat = requests.get(country_url,headers=headers)
country = pd.json_normalize(country_dat.json()['api']['countries'])
country

# %%
print(country[country.country == "England"])
# League
league_url = "https://api-football-v1.p.rapidapi.com/v3/leagues"
all_leagues = requests.get(league_url,headers=headers)
leagues_dat = pd.json_normalize(all_leagues.json()['response'])
# Out:
#     country code                                      flag
# 48  England   GB  https://media.api-sports.io/flags/gb.svg

# %%
leagues_dat[leagues_dat['country.name'] == "England"]
leagues_dat[leagues_dat['league.name'] == "Premier League"]
# Out:
#                                                 seasons  league.id  \
# 5     [{'year': 2010, 'start': '2010-08-14', 'end': ...         39
# 28    [{'year': 2011, 'start': '2011-07-08', 'end': ...        333
# 48    [{'year': 2011, 'start': '2011-10-14', 'end': ...        233
# 53    [{'year': 2011, 'start': '2010-09-05', 'end': ...        570
# 86    [{'year': 2011, 'start': '2011-08-12', 'end': ...        110
# 91    [{'year': 2011, 'start': '2011-09-11', 'end': ...        322
# 94    [{'year': 2011, 'start': '2011-12-30', 'end': ...        330
# 102   [{'year': 2011, 'start': '2011-09-03', 'end': ...        380
# 106   [{'year': 2011, 'start': '2011-10-22', 'end': ...        390
# 121   [{'year': 2012, 'start': '2012-02-26', 'end': ...        422
# 126   [{'year': 2012, 'start': '2012-09-24', 'end': ...        585
# 150   [{'year': 2012, 'start': '2012-03-31', 'end': ...        342
# 152   [{'year': 2012, 'start': '2012-03-24', 'end': ...        116
# ...

# %%
url = "https://api-football-v1.p.rapidapi.com/v3/fixtures"
querystring = {"date":"2021-01-29"}
#fixture_example = requests.get(url, headers=headers, params=querystring)
#print(fixture_example.json())

## Teams Data
url = "https://api-football-v1.p.rapidapi.com/v3/teams"
headers = {
	"X-RapidAPI-Key": "64f82034damsh6dd2baeda9216d1p173668jsnddc6687707f5",
	"X-RapidAPI-Host": "api-football-v1.p.rapidapi.com"
}

teams_response = requests.get(url, headers=headers)
print(teams_response.json())
# Out:
# {'get': 'teams', 'parameters': [], 'errors': {'required': 'At least one parameter is required.'}, 'results': 0, 'paging': {'current': 1, 'total': 1}, 'response': []}

# %%
dat = pd.json_normalize(response.json()['response'])
# Out:
#      fixture.id               fixture.referee fixture.timezone  \
# 0        663684                    A. Sánchez              UTC
# 1        714615                          None              UTC
# 2        658875                 L. Rey Hilfer              UTC
# 3        653560                      I. Lopez              UTC
# 4        652833                  F. Hernández              UTC
# ..          ...                           ...              ...
# 110      324160                    N. Vignolo              UTC
# 111      328737  Rodrigo José Pereira de Lima              UTC
# 112      328739               Thayslane Costa              UTC
# 113      656228                   W. Mosquera              UTC
# 114      653554                   D. Quintero              UTC
#
#                   fixture.date  fixture.timestamp  fixture.periods.first  \
# 0    2021-01-29T00:00:00+00:00         1611878400           1.611878e+09
# ...

# %%
response.json()['response']
# Out:
# [{'fixture': {'id': 663684,
#    'referee': 'A. Sánchez',
#    'timezone': 'UTC',
#    'date': '2021-01-29T00:00:00+00:00',
#    'timestamp': 1611878400,
#    'periods': {'first': 1611878400, 'second': 1611882000},
#    'venue': {'id': 1207,
#     'name': 'Estadio Rommel Fernández Gutiérrez',
#     'city': 'Ciudad de Panamá'},
#    'status': {'long': 'Match Finished', 'short': 'FT', 'elapsed': 90}},
#   'league': {'id': 10,
#    'name': 'Friendlies',
#    'country': 'World',
#    'logo': 'https://media.api-sports.io/football/leagues/10.png',
#    'flag': None,
#    'season': 2021,
#    'round': 'Friendlies 1'},
#   'teams': {'home': {'id': 11,
#     'name': 'Panama',
#     'logo': 'https://media.api-sports.io/football/teams/11.png',
#     'winner': None},
#    'away': {'id': 14,
#     'name': 'Serbia',
#     'logo': 'https://media.api-sports.io/football/teams/14.png',
#     'winner': None}},
#   'goals': {'home': 0, 'away': 0},
#   'score': {'halftime': {'home': 0, 'away': 0},
# ...
